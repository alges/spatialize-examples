# %% [markdown]
# # Searching for Optimal ESI Parameters
#
# Spatialize has a built-in method for searching for optimal parameters. This document provides an overview on this functionality.

# %% [markdown]
# ## The esi_hparams_search() function
